# %%
import sys
sys.path.append('../../data')

import tensorflow as tf 
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
from preprocess import get_data
from model_param import ConvulationParameters, MaxPoolParameters
from cnn1 import generateCNN
from cnn2 import generateCNN2
from cnn3 import generateCNN3

# %%
def write_to_file(final_accuracy, final_loss, val_accuracy, val_loss, learning_rate, 
                  batch_size, conv_param, maxpool_param, dropout_rate, dense_unit):
    
    output_string = f"CNN: Test Accuracy is {final_accuracy}, Test Loss is {final_loss} \n"
    output_string += f"Val Accuracy is {val_accuracy}, Val Loss is {val_loss} \n"
    output_string += f"Batch size - {batch_size}, Learning Rate - {learning_rate}, Dropout Rate - {dropout_rate}, Dense - {dense_unit} \n"
    output_string += f"Conv2d - {conv_param.GetString()}, MaxPool2D - {maxpool_param.GetString()}. \n\n\n"
    
    file1 = open('cnn1_tests.txt', 'a')
    file1.write(output_string)
    file1.close()

def explore_models(x, y):
    conv2ds = [ConvulationParameters(features=16, kernel=(3,3), strides=(1,1), padding='same'),
              ConvulationParameters(features=32, kernel=(3,3), strides=(1,1), padding='same'),
               ConvulationParameters(features=16, kernel=(5,5), strides=(1,1), padding='same'),
               ConvulationParameters(features=32, kernel=(5,5), strides=(1,1), padding='same')]
    maxpools = [MaxPoolParameters(pool=(2,2), stride=(2,2))]
    dropout_rates = [0.1, 0.2]
    dense_units = [16, 32]

    batch_sizes = [64]
    learning_rates = [0.001, 0.01]
    
    for learning_rate in learning_rates:
        for batch_size in batch_sizes:
            for conv_param in conv2ds:
                for maxpool_param in maxpools:
                    for dropout_rate in dropout_rates:
                        for dense_unit in dense_units:
                            model = generateCNN(conv_param, maxpool_param, dropout_rate, dense_unit)
                            model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
                            history = model.fit(x=x, y=y, batch_size=batch_size, epochs=30, validation_split=0.2, verbose=2)
                            final_accuracy, final_loss = history.history['accuracy'][-1], history.history['loss'][-1]
                            val_accuracy, val_loss = history.history['val_accuracy'][-1], history.history['val_loss'][-1]
                            write_to_file(final_accuracy, final_loss, val_accuracy, val_loss, 
                                          learning_rate, batch_size, conv_param, maxpool_param, 
                                          dropout_rate, dense_unit)

# %%
_DEFAULT_TRAIN_FILEPATH = ['../../data/train_data_1.gz', '../../data/train_data_2.gz', '../../data/train_data_3.gz', '../../data/train_data_4.gz']
_DEFAULT_TEST_FILEPATH = '../../data/test_data.gz'
x_train, y_train, x_test, y_test = get_data(_DEFAULT_TRAIN_FILEPATH, _DEFAULT_TEST_FILEPATH)

# %%
explore_models(x=x_train, y=y_train)
# Out:
# Epoch 1/30
# 359/359 - 66s - loss: 1.6975 - accuracy: 0.3417 - val_loss: 1.8594 - val_accuracy: 0.2621
# Epoch 2/30
# 359/359 - 72s - loss: 1.4265 - accuracy: 0.4570 - val_loss: 1.4084 - val_accuracy: 0.4603
# Epoch 3/30
# 359/359 - 73s - loss: 1.2948 - accuracy: 0.5106 - val_loss: 1.3474 - val_accuracy: 0.4962
# Epoch 4/30
# 359/359 - 71s - loss: 1.2131 - accuracy: 0.5426 - val_loss: 1.3188 - val_accuracy: 0.5005
# Epoch 5/30
# 359/359 - 71s - loss: 1.1384 - accuracy: 0.5749 - val_loss: 1.2937 - val_accuracy: 0.5108
# Epoch 6/30
# 359/359 - 76s - loss: 1.0804 - accuracy: 0.5989 - val_loss: 1.2487 - val_accuracy: 0.5348
# Epoch 7/30
# 359/359 - 74s - loss: 1.0214 - accuracy: 0.6202 - val_loss: 1.3096 - val_accuracy: 0.5098
# Epoch 8/30
# 359/359 - 73s - loss: 0.9676 - accuracy: 0.6428 - val_loss: 1.1846 - val_accuracy: 0.5582
# Epoch 9/30
# 359/359 - 72s - loss: 0.9199 - accuracy: 0.6581 - val_loss: 1.2784 - val_accuracy: 0.5385
# Epoch 10/30
# 359/359 - 74s - loss: 0.8774 - accuracy: 0.6795 - val_loss: 1.2287 - val_accuracy: 0.5545
# Epoch 11/30
# 359/359 - 73s - loss: 0.8306 - accuracy: 0.6957 - val_loss: 1.2332 - val_accuracy: 0.5655
# Epoch 12/30
# 359/359 - 77s - loss: 0.7817 - accuracy: 0.7143 - val_loss: 1.2585 - val_accuracy: 0.5564
# Epoch 13/30
# 359/359 - 78s - loss: 0.7451 - accuracy: 0.7314 - val_loss: 1.3254 - val_accuracy: 0.5204
# Epoch 14/30
# 359/359 - 81s - loss: 0.7072 - accuracy: 0.7434 - val_loss: 1.2421 - val_accuracy: 0.5625
# Epoch 15/30
# 359/359 - 81s - loss: 0.6788 - accuracy: 0.7534 - val_loss: 1.3343 - val_accuracy: 0.5390
# Epoch 16/30
# 359/359 - 80s - loss: 0.6418 - accuracy: 0.7655 - val_loss: 1.3489 - val_accuracy: 0.5453
# Epoch 17/30
# 359/359 - 84s - loss: 0.6082 - accuracy: 0.7806 - val_loss: 1.3678 - val_accuracy: 0.5568
# Epoch 18/30
# 359/359 - 82s - loss: 0.5823 - accuracy: 0.7899 - val_loss: 1.4781 - val_accuracy: 0.5500
# Epoch 19/30
# 359/359 - 82s - loss: 0.5568 - accuracy: 0.7984 - val_loss: 1.4139 - val_accuracy: 0.5533
# Epoch 20/30
# 359/359 - 83s - loss: 0.5323 - accuracy: 0.8080 - val_loss: 1.3878 - val_accuracy: 0.5611
# Epoch 21/30
# 359/359 - 84s - loss: 0.5127 - accuracy: 0.8156 - val_loss: 1.4255 - val_accuracy: 0.5401
# Epoch 22/30
# 359/359 - 84s - loss: 0.4990 - accuracy: 0.8201 - val_loss: 1.5431 - val_accuracy: 0.5477
# Epoch 23/30
# 359/359 - 82s - loss: 0.4786 - accuracy: 0.8277 - val_loss: 1.4654 - val_accuracy: 0.5697
# Epoch 24/30
# 359/359 - 83s - loss: 0.4583 - accuracy: 0.8338 - val_loss: 1.4081 - val_accuracy: 0.5632
# Epoch 25/30
# 359/359 - 83s - loss: 0.4368 - accuracy: 0.8429 - val_loss: 1.5521 - val_accuracy: 0.5256
# Epoch 26/30
# 359/359 - 83s - loss: 0.4155 - accuracy: 0.8513 - val_loss: 1.4404 - val_accuracy: 0.5691
# Epoch 27/30
# 359/359 - 84s - loss: 0.4084 - accuracy: 0.8536 - val_loss: 1.4431 - val_accuracy: 0.5761
# Epoch 28/30
# 359/359 - 84s - loss: 0.4050 - accuracy: 0.8545 - val_loss: 2.0551 - val_accuracy: 0.4441
# Epoch 29/30
# 359/359 - 84s - loss: 0.3779 - accuracy: 0.8635 - val_loss: 1.6522 - val_accuracy: 0.5583
# Epoch 30/30
# 359/359 - 84s - loss: 0.3796 - accuracy: 0.8631 - val_loss: 1.5363 - val_accuracy: 0.5610
# Epoch 1/30
# 359/359 - 84s - loss: 1.6292 - accuracy: 0.3605 - val_loss: 1.8180 - val_accuracy: 0.3299
# Epoch 2/30
# 359/359 - 87s - loss: 1.3744 - accuracy: 0.4668 - val_loss: 1.4494 - val_accuracy: 0.4291
# Epoch 3/30
# 359/359 - 85s - loss: 1.2514 - accuracy: 0.5231 - val_loss: 1.3059 - val_accuracy: 0.5024
# Epoch 4/30
# 359/359 - 85s - loss: 1.1634 - accuracy: 0.5594 - val_loss: 1.2991 - val_accuracy: 0.5179
# Epoch 5/30
# 359/359 - 84s - loss: 1.0918 - accuracy: 0.5871 - val_loss: 1.3295 - val_accuracy: 0.4941
# Epoch 6/30
# 359/359 - 84s - loss: 1.0208 - accuracy: 0.6180 - val_loss: 1.2849 - val_accuracy: 0.5232
# Epoch 7/30
# 359/359 - 84s - loss: 0.9598 - accuracy: 0.6404 - val_loss: 1.2866 - val_accuracy: 0.5261
# Epoch 8/30
# 359/359 - 83s - loss: 0.8982 - accuracy: 0.6664 - val_loss: 1.6222 - val_accuracy: 0.4279
# Epoch 9/30
# 359/359 - 85s - loss: 0.8516 - accuracy: 0.6841 - val_loss: 1.3743 - val_accuracy: 0.5124
# Epoch 10/30
# 359/359 - 86s - loss: 0.7884 - accuracy: 0.7093 - val_loss: 1.4019 - val_accuracy: 0.5263
# Epoch 11/30
# 359/359 - 84s - loss: 0.7440 - accuracy: 0.7239 - val_loss: 1.2527 - val_accuracy: 0.5758
# Epoch 12/30
# 359/359 - 83s - loss: 0.6818 - accuracy: 0.7510 - val_loss: 1.3121 - val_accuracy: 0.5397
# Epoch 13/30
# 359/359 - 84s - loss: 0.6477 - accuracy: 0.7599 - val_loss: 1.2837 - val_accuracy: 0.5611
# Epoch 14/30
# 359/359 - 84s - loss: 0.6036 - accuracy: 0.7800 - val_loss: 1.6763 - val_accuracy: 0.4911
# Epoch 15/30
# 359/359 - 84s - loss: 0.5647 - accuracy: 0.7939 - val_loss: 1.3133 - val_accuracy: 0.5613
# Epoch 16/30
# 359/359 - 84s - loss: 0.5235 - accuracy: 0.8099 - val_loss: 1.5106 - val_accuracy: 0.5388
# Epoch 17/30
# 359/359 - 85s - loss: 0.4908 - accuracy: 0.8197 - val_loss: 1.4335 - val_accuracy: 0.5590
# Epoch 18/30
# 359/359 - 85s - loss: 0.4638 - accuracy: 0.8288 - val_loss: 1.4536 - val_accuracy: 0.5700
# Epoch 19/30
# 359/359 - 84s - loss: 0.4443 - accuracy: 0.8386 - val_loss: 1.5411 - val_accuracy: 0.5430
# Epoch 20/30
# 359/359 - 85s - loss: 0.4159 - accuracy: 0.8495 - val_loss: 1.5980 - val_accuracy: 0.5589
# Epoch 21/30
# 359/359 - 85s - loss: 0.4008 - accuracy: 0.8563 - val_loss: 1.8216 - val_accuracy: 0.4969
# Epoch 22/30
# 359/359 - 84s - loss: 0.3735 - accuracy: 0.8648 - val_loss: 1.6040 - val_accuracy: 0.5630
# Epoch 23/30
# 359/359 - 85s - loss: 0.3606 - accuracy: 0.8666 - val_loss: 1.8266 - val_accuracy: 0.5334
# Epoch 24/30
# 359/359 - 90s - loss: 0.3462 - accuracy: 0.8740 - val_loss: 1.8237 - val_accuracy: 0.5251
# Epoch 25/30
# 359/359 - 86s - loss: 0.3314 - accuracy: 0.8805 - val_loss: 1.9083 - val_accuracy: 0.5566
# Epoch 26/30
# 359/359 - 83s - loss: 0.3275 - accuracy: 0.8834 - val_loss: 1.8519 - val_accuracy: 0.5387
# Epoch 27/30
# 359/359 - 85s - loss: 0.3056 - accuracy: 0.8893 - val_loss: 1.7599 - val_accuracy: 0.5409
# Epoch 28/30
# 359/359 - 87s - loss: 0.2987 - accuracy: 0.8921 - val_loss: 1.8601 - val_accuracy: 0.5397
# Epoch 29/30
# 359/359 - 84s - loss: 0.2891 - accuracy: 0.8957 - val_loss: 1.9445 - val_accuracy: 0.5094
# Epoch 30/30
# 359/359 - 85s - loss: 0.2750 - accuracy: 0.9008 - val_loss: 1.8652 - val_accuracy: 0.5402
# Epoch 1/30
# 359/359 - 84s - loss: 1.6916 - accuracy: 0.3341 - val_loss: 1.7738 - val_accuracy: 0.3201
# Epoch 2/30
# 359/359 - 84s - loss: 1.4489 - accuracy: 0.4427 - val_loss: 1.6491 - val_accuracy: 0.3776
# Epoch 3/30
# 359/359 - 85s - loss: 1.3419 - accuracy: 0.4868 - val_loss: 1.4229 - val_accuracy: 0.4500
# Epoch 4/30
# 359/359 - 84s - loss: 1.2653 - accuracy: 0.5156 - val_loss: 1.4332 - val_accuracy: 0.4586
# Epoch 5/30
# 359/359 - 86s - loss: 1.2086 - accuracy: 0.5398 - val_loss: 1.3361 - val_accuracy: 0.4793
# Epoch 6/30
# 359/359 - 84s - loss: 1.1595 - accuracy: 0.5589 - val_loss: 1.4222 - val_accuracy: 0.4439
# Epoch 7/30
# 359/359 - 84s - loss: 1.1132 - accuracy: 0.5766 - val_loss: 1.4450 - val_accuracy: 0.4424
# Epoch 8/30
# 359/359 - 86s - loss: 1.0739 - accuracy: 0.5942 - val_loss: 1.3194 - val_accuracy: 0.4963
# Epoch 9/30
# 359/359 - 85s - loss: 1.0440 - accuracy: 0.6094 - val_loss: 1.4687 - val_accuracy: 0.4493
# Epoch 10/30
# 359/359 - 85s - loss: 1.0150 - accuracy: 0.6190 - val_loss: 1.4068 - val_accuracy: 0.4690
# Epoch 11/30
# 359/359 - 85s - loss: 0.9833 - accuracy: 0.6290 - val_loss: 1.4480 - val_accuracy: 0.4345
# Epoch 12/30
# 359/359 - 85s - loss: 0.9463 - accuracy: 0.6458 - val_loss: 1.4247 - val_accuracy: 0.4558
# Epoch 13/30
# 359/359 - 86s - loss: 0.9247 - accuracy: 0.6549 - val_loss: 1.1933 - val_accuracy: 0.5549
# Epoch 14/30
# 359/359 - 84s - loss: 0.8993 - accuracy: 0.6642 - val_loss: 1.2701 - val_accuracy: 0.5240
# Epoch 15/30
# 359/359 - 87s - loss: 0.8683 - accuracy: 0.6754 - val_loss: 1.3351 - val_accuracy: 0.4908
# Epoch 16/30
# 359/359 - 85s - loss: 0.8498 - accuracy: 0.6837 - val_loss: 1.7865 - val_accuracy: 0.3490
# Epoch 17/30
# 359/359 - 85s - loss: 0.8263 - accuracy: 0.6935 - val_loss: 1.3423 - val_accuracy: 0.5021
# Epoch 18/30
# 359/359 - 85s - loss: 0.8093 - accuracy: 0.6968 - val_loss: 1.3404 - val_accuracy: 0.5037
# Epoch 19/30
# 359/359 - 86s - loss: 0.7860 - accuracy: 0.7079 - val_loss: 1.2080 - val_accuracy: 0.5583
# Epoch 20/30
# 359/359 - 84s - loss: 0.7656 - accuracy: 0.7194 - val_loss: 1.3868 - val_accuracy: 0.4887
# Epoch 21/30
# 359/359 - 84s - loss: 0.7424 - accuracy: 0.7246 - val_loss: 1.2618 - val_accuracy: 0.5437
# Epoch 22/30
# 359/359 - 87s - loss: 0.7265 - accuracy: 0.7301 - val_loss: 1.6816 - val_accuracy: 0.4282
# Epoch 23/30
# 359/359 - 85s - loss: 0.7135 - accuracy: 0.7344 - val_loss: 1.2956 - val_accuracy: 0.5310
# Epoch 24/30
# 359/359 - 84s - loss: 0.6879 - accuracy: 0.7455 - val_loss: 1.2181 - val_accuracy: 0.5610
# Epoch 25/30
# 359/359 - 84s - loss: 0.6816 - accuracy: 0.7487 - val_loss: 1.2074 - val_accuracy: 0.5665
# Epoch 26/30
# 359/359 - 86s - loss: 0.6685 - accuracy: 0.7555 - val_loss: 1.2926 - val_accuracy: 0.5352
# Epoch 27/30
# 359/359 - 84s - loss: 0.6505 - accuracy: 0.7616 - val_loss: 1.2208 - val_accuracy: 0.5643
# Epoch 28/30
# 359/359 - 87s - loss: 0.6366 - accuracy: 0.7663 - val_loss: 1.2720 - val_accuracy: 0.5484
# Epoch 29/30
# 359/359 - 86s - loss: 0.6256 - accuracy: 0.7695 - val_loss: 1.2812 - val_accuracy: 0.5456
# Epoch 30/30
# 359/359 - 83s - loss: 0.6143 - accuracy: 0.7720 - val_loss: 1.4282 - val_accuracy: 0.5003
# Epoch 1/30
# 359/359 - 85s - loss: 1.7018 - accuracy: 0.3341 - val_loss: 1.9964 - val_accuracy: 0.1719
# Epoch 2/30
# 359/359 - 86s - loss: 1.4278 - accuracy: 0.4504 - val_loss: 1.5316 - val_accuracy: 0.3985
# Epoch 3/30
# 359/359 - 88s - loss: 1.2962 - accuracy: 0.5032 - val_loss: 1.5120 - val_accuracy: 0.4211
# Epoch 4/30
# 359/359 - 85s - loss: 1.2162 - accuracy: 0.5368 - val_loss: 1.3933 - val_accuracy: 0.4852
# Epoch 5/30
# 359/359 - 85s - loss: 1.1535 - accuracy: 0.5626 - val_loss: 1.3318 - val_accuracy: 0.4941
# Epoch 6/30
# 359/359 - 87s - loss: 1.1076 - accuracy: 0.5826 - val_loss: 1.6143 - val_accuracy: 0.3744
# Epoch 7/30
# 359/359 - 84s - loss: 1.0524 - accuracy: 0.6009 - val_loss: 1.2756 - val_accuracy: 0.5186
# Epoch 8/30
# 359/359 - 86s - loss: 1.0107 - accuracy: 0.6192 - val_loss: 1.2913 - val_accuracy: 0.5110
# Epoch 9/30
# 359/359 - 85s - loss: 0.9744 - accuracy: 0.6316 - val_loss: 1.3412 - val_accuracy: 0.5045
# Epoch 10/30
# 359/359 - 86s - loss: 0.9363 - accuracy: 0.6498 - val_loss: 1.2628 - val_accuracy: 0.5219
# Epoch 11/30
# 359/359 - 85s - loss: 0.8953 - accuracy: 0.6643 - val_loss: 1.6857 - val_accuracy: 0.3619
# Epoch 12/30
# 359/359 - 85s - loss: 0.8633 - accuracy: 0.6792 - val_loss: 1.2834 - val_accuracy: 0.5176
# Epoch 13/30
# 359/359 - 86s - loss: 0.8362 - accuracy: 0.6904 - val_loss: 1.3897 - val_accuracy: 0.5033
# Epoch 14/30
# 359/359 - 84s - loss: 0.7920 - accuracy: 0.7045 - val_loss: 1.3587 - val_accuracy: 0.4960
# Epoch 15/30
# 359/359 - 85s - loss: 0.7657 - accuracy: 0.7145 - val_loss: 1.3134 - val_accuracy: 0.5132
# Epoch 16/30
# 359/359 - 85s - loss: 0.7362 - accuracy: 0.7279 - val_loss: 1.2804 - val_accuracy: 0.5331
# Epoch 17/30
# 359/359 - 86s - loss: 0.7123 - accuracy: 0.7350 - val_loss: 1.2673 - val_accuracy: 0.5427
# Epoch 18/30
# 359/359 - 84s - loss: 0.6859 - accuracy: 0.7476 - val_loss: 1.2674 - val_accuracy: 0.5488
# Epoch 19/30
# 359/359 - 85s - loss: 0.6603 - accuracy: 0.7566 - val_loss: 1.4010 - val_accuracy: 0.4991
# Epoch 20/30
# 359/359 - 86s - loss: 0.6371 - accuracy: 0.7651 - val_loss: 1.2924 - val_accuracy: 0.5392
# Epoch 21/30
# 359/359 - 85s - loss: 0.6152 - accuracy: 0.7749 - val_loss: 1.2656 - val_accuracy: 0.5515
# Epoch 22/30
# 359/359 - 85s - loss: 0.6007 - accuracy: 0.7801 - val_loss: 1.5556 - val_accuracy: 0.4857
# Epoch 23/30
# 359/359 - 87s - loss: 0.5781 - accuracy: 0.7850 - val_loss: 1.4667 - val_accuracy: 0.5169
# Epoch 24/30
# 359/359 - 85s - loss: 0.5517 - accuracy: 0.7985 - val_loss: 1.5371 - val_accuracy: 0.5148
# Epoch 25/30
# 359/359 - 85s - loss: 0.5410 - accuracy: 0.8000 - val_loss: 1.3220 - val_accuracy: 0.5568
# Epoch 26/30
# 359/359 - 86s - loss: 0.5291 - accuracy: 0.8053 - val_loss: 1.3911 - val_accuracy: 0.5357
# Epoch 27/30
# 359/359 - 89s - loss: 0.5021 - accuracy: 0.8126 - val_loss: 1.5149 - val_accuracy: 0.5235
# Epoch 28/30
# Epoch 21/30
# 359/359 - 190s - loss: 0.2316 - accuracy: 0.9183 - val_loss: 1.7267 - val_accuracy: 0.5585
# Epoch 22/30
# 359/359 - 186s - loss: 0.2366 - accuracy: 0.9169 - val_loss: 1.9465 - val_accuracy: 0.5143
# Epoch 23/30
# 359/359 - 187s - loss: 0.2087 - accuracy: 0.9288 - val_loss: 1.9960 - val_accuracy: 0.5366
# Epoch 24/30
# 359/359 - 186s - loss: 0.2086 - accuracy: 0.9268 - val_loss: 1.9255 - val_accuracy: 0.5420
# Epoch 25/30
# 359/359 - 188s - loss: 0.1788 - accuracy: 0.9389 - val_loss: 1.6705 - val_accuracy: 0.5923
# Epoch 26/30
# 359/359 - 186s - loss: 0.1800 - accuracy: 0.9380 - val_loss: 1.8531 - val_accuracy: 0.5615
# Epoch 27/30
# 359/359 - 186s - loss: 0.1864 - accuracy: 0.9339 - val_loss: 2.0357 - val_accuracy: 0.5507
# Epoch 28/30
# 359/359 - 187s - loss: 0.1743 - accuracy: 0.9390 - val_loss: 1.8536 - val_accuracy: 0.5834
# Epoch 29/30
# 359/359 - 187s - loss: 0.1590 - accuracy: 0.9461 - val_loss: 1.8904 - val_accuracy: 0.5718
# Epoch 30/30
# 359/359 - 185s - loss: 0.1526 - accuracy: 0.9482 - val_loss: 1.9966 - val_accuracy: 0.5653
# Epoch 1/30
# 359/359 - 188s - loss: 1.6269 - accuracy: 0.3602 - val_loss: 2.1886 - val_accuracy: 0.1822
# Epoch 2/30
# 359/359 - 187s - loss: 1.3266 - accuracy: 0.4955 - val_loss: 1.5375 - val_accuracy: 0.4188
# Epoch 3/30
# 359/359 - 187s - loss: 1.1866 - accuracy: 0.5489 - val_loss: 1.3705 - val_accuracy: 0.4807
# Epoch 4/30
# 359/359 - 188s - loss: 1.0829 - accuracy: 0.5918 - val_loss: 1.3905 - val_accuracy: 0.4615
# Epoch 5/30
# 359/359 - 187s - loss: 1.0036 - accuracy: 0.6255 - val_loss: 1.2108 - val_accuracy: 0.5479
# Epoch 6/30
# 359/359 - 188s - loss: 0.9070 - accuracy: 0.6650 - val_loss: 1.4808 - val_accuracy: 0.4415
# Epoch 7/30
# 359/359 - 192s - loss: 0.8238 - accuracy: 0.6960 - val_loss: 1.3132 - val_accuracy: 0.5347
# Epoch 8/30
# 359/359 - 187s - loss: 0.7385 - accuracy: 0.7289 - val_loss: 1.2810 - val_accuracy: 0.5554
# Epoch 9/30
# 359/359 - 188s - loss: 0.6522 - accuracy: 0.7635 - val_loss: 1.3030 - val_accuracy: 0.5495
# Epoch 10/30
# 359/359 - 189s - loss: 0.5696 - accuracy: 0.7950 - val_loss: 1.4734 - val_accuracy: 0.5155
# Epoch 11/30
# 359/359 - 189s - loss: 0.5032 - accuracy: 0.8161 - val_loss: 1.4557 - val_accuracy: 0.5559
# Epoch 12/30
# 359/359 - 188s - loss: 0.4274 - accuracy: 0.8450 - val_loss: 1.4855 - val_accuracy: 0.5202
# Epoch 13/30
# 359/359 - 141s - loss: 0.9884 - accuracy: 0.6305 - val_loss: 1.3684 - val_accuracy: 0.4915
# Epoch 7/30
# 359/359 - 141s - loss: 0.9176 - accuracy: 0.6563 - val_loss: 1.2438 - val_accuracy: 0.5225
# Epoch 8/30
# 359/359 - 142s - loss: 0.8385 - accuracy: 0.6907 - val_loss: 1.2811 - val_accuracy: 0.5331
# Epoch 9/30
# 359/359 - 141s - loss: 0.7552 - accuracy: 0.7240 - val_loss: 1.2784 - val_accuracy: 0.5448
# Epoch 10/30
# 359/359 - 150s - loss: 0.6859 - accuracy: 0.7465 - val_loss: 1.3101 - val_accuracy: 0.5596
# Epoch 11/30
# 359/359 - 138s - loss: 0.6142 - accuracy: 0.7734 - val_loss: 1.3264 - val_accuracy: 0.5441
# Epoch 12/30
# 359/359 - 140s - loss: 0.5550 - accuracy: 0.7991 - val_loss: 1.5941 - val_accuracy: 0.4934
# Epoch 13/30
# 359/359 - 143s - loss: 0.4994 - accuracy: 0.8206 - val_loss: 1.3833 - val_accuracy: 0.5655
# Epoch 14/30
# 359/359 - 140s - loss: 0.4565 - accuracy: 0.8325 - val_loss: 1.7026 - val_accuracy: 0.4909
# Epoch 15/30
# 359/359 - 142s - loss: 0.4083 - accuracy: 0.8541 - val_loss: 1.4968 - val_accuracy: 0.5437
# Epoch 16/30
# 359/359 - 141s - loss: 0.3797 - accuracy: 0.8646 - val_loss: 1.5924 - val_accuracy: 0.5603
# Epoch 17/30
# 359/359 - 144s - loss: 0.3387 - accuracy: 0.8778 - val_loss: 1.6950 - val_accuracy: 0.5312
# Epoch 18/30
# 359/359 - 142s - loss: 0.3153 - accuracy: 0.8878 - val_loss: 1.8715 - val_accuracy: 0.5246
# Epoch 19/30
# 359/359 - 142s - loss: 0.2861 - accuracy: 0.8986 - val_loss: 1.6778 - val_accuracy: 0.5575
# Epoch 20/30
# 359/359 - 141s - loss: 0.2775 - accuracy: 0.9033 - val_loss: 1.9905 - val_accuracy: 0.5249
# Epoch 21/30
# 359/359 - 142s - loss: 0.2571 - accuracy: 0.9096 - val_loss: 1.8194 - val_accuracy: 0.5373
# Epoch 22/30
# 359/359 - 140s - loss: 0.2488 - accuracy: 0.9119 - val_loss: 1.8951 - val_accuracy: 0.5219
# Epoch 23/30
# 359/359 - 145s - loss: 0.2323 - accuracy: 0.9181 - val_loss: 1.8760 - val_accuracy: 0.5571
# Epoch 24/30
# 359/359 - 142s - loss: 0.2187 - accuracy: 0.9230 - val_loss: 1.8587 - val_accuracy: 0.5615
# Epoch 25/30
# 359/359 - 140s - loss: 0.2153 - accuracy: 0.9219 - val_loss: 1.9105 - val_accuracy: 0.5568
# Epoch 26/30
# 359/359 - 142s - loss: 0.2089 - accuracy: 0.9263 - val_loss: 1.9580 - val_accuracy: 0.5232
# Epoch 27/30
# 359/359 - 140s - loss: 0.1990 - accuracy: 0.9294 - val_loss: 2.1727 - val_accuracy: 0.5380
# Epoch 28/30
# 359/359 - 142s - loss: 0.1867 - accuracy: 0.9345 - val_loss: 1.9157 - val_accuracy: 0.5552
# Epoch 29/30
# 359/359 - 142s - loss: 0.1732 - accuracy: 0.9382 - val_loss: 1.9822 - val_accuracy: 0.5704
# Epoch 30/30
# 359/359 - 148s - loss: 0.1728 - accuracy: 0.9386 - val_loss: 2.1125 - val_accuracy: 0.5714
# Epoch 1/30
# 359/359 - 143s - loss: 1.6734 - accuracy: 0.3455 - val_loss: 1.8470 - val_accuracy: 0.3079
# Epoch 2/30
# 359/359 - 144s - loss: 1.4393 - accuracy: 0.4471 - val_loss: 1.6407 - val_accuracy: 0.3837
# Epoch 3/30
# 359/359 - 144s - loss: 1.3290 - accuracy: 0.4945 - val_loss: 1.4966 - val_accuracy: 0.4209
# Epoch 4/30
# 359/359 - 146s - loss: 1.2492 - accuracy: 0.5267 - val_loss: 1.7538 - val_accuracy: 0.3001
# Epoch 5/30
# 359/359 - 143s - loss: 1.1784 - accuracy: 0.5508 - val_loss: 1.3921 - val_accuracy: 0.4427
# Epoch 6/30
# 359/359 - 146s - loss: 1.1201 - accuracy: 0.5793 - val_loss: 1.4302 - val_accuracy: 0.4720
# Epoch 7/30
# 359/359 - 144s - loss: 1.0751 - accuracy: 0.5933 - val_loss: 1.3804 - val_accuracy: 0.4667
# Epoch 8/30
# 359/359 - 147s - loss: 1.0308 - accuracy: 0.6152 - val_loss: 1.3294 - val_accuracy: 0.4892
# Epoch 9/30
# 359/359 - 144s - loss: 0.9838 - accuracy: 0.6363 - val_loss: 1.4361 - val_accuracy: 0.4552
# Epoch 10/30
# 359/359 - 145s - loss: 0.9445 - accuracy: 0.6476 - val_loss: 1.3197 - val_accuracy: 0.5110
# Epoch 11/30
# 359/359 - 144s - loss: 0.8924 - accuracy: 0.6703 - val_loss: 1.2929 - val_accuracy: 0.5101
# Epoch 12/30
# 359/359 - 147s - loss: 0.8556 - accuracy: 0.6849 - val_loss: 1.3890 - val_accuracy: 0.4807
# Epoch 13/30
# 359/359 - 144s - loss: 0.8140 - accuracy: 0.6987 - val_loss: 1.1876 - val_accuracy: 0.5568
# Epoch 14/30
# 359/359 - 146s - loss: 0.7780 - accuracy: 0.7141 - val_loss: 1.3856 - val_accuracy: 0.4946
# Epoch 15/30
# 359/359 - 143s - loss: 0.7389 - accuracy: 0.7283 - val_loss: 1.3387 - val_accuracy: 0.5322
# Epoch 16/30
# 359/359 - 146s - loss: 0.7107 - accuracy: 0.7400 - val_loss: 1.3067 - val_accuracy: 0.5122
# Epoch 17/30
# 359/359 - 144s - loss: 0.6712 - accuracy: 0.7560 - val_loss: 1.2387 - val_accuracy: 0.5528
# Epoch 18/30
# 359/359 - 148s - loss: 0.6366 - accuracy: 0.7712 - val_loss: 1.5220 - val_accuracy: 0.4794
# Epoch 19/30
# 359/359 - 143s - loss: 0.6146 - accuracy: 0.7766 - val_loss: 1.3266 - val_accuracy: 0.5355
# Epoch 20/30
# 359/359 - 145s - loss: 0.5791 - accuracy: 0.7889 - val_loss: 1.4311 - val_accuracy: 0.5347
# Epoch 21/30
# 359/359 - 144s - loss: 0.5571 - accuracy: 0.7961 - val_loss: 1.4197 - val_accuracy: 0.5296
# Epoch 22/30
# 359/359 - 143s - loss: 0.5324 - accuracy: 0.8084 - val_loss: 1.3836 - val_accuracy: 0.5369
# Epoch 23/30
# 359/359 - 146s - loss: 0.5142 - accuracy: 0.8119 - val_loss: 1.3336 - val_accuracy: 0.5599
# Epoch 24/30
# 359/359 - 144s - loss: 0.4929 - accuracy: 0.8214 - val_loss: 1.4300 - val_accuracy: 0.5446
# Epoch 25/30
# 359/359 - 145s - loss: 0.4727 - accuracy: 0.8296 - val_loss: 1.5539 - val_accuracy: 0.5017
# Epoch 26/30
# 359/359 - 145s - loss: 0.4552 - accuracy: 0.8343 - val_loss: 1.5824 - val_accuracy: 0.4808
# Epoch 27/30
# 359/359 - 144s - loss: 0.4394 - accuracy: 0.8419 - val_loss: 1.5494 - val_accuracy: 0.5251
# Epoch 28/30
# 359/359 - 144s - loss: 0.4328 - accuracy: 0.8443 - val_loss: 1.5993 - val_accuracy: 0.5383
# Epoch 29/30
# 359/359 - 145s - loss: 0.4067 - accuracy: 0.8523 - val_loss: 1.5927 - val_accuracy: 0.5385
# Epoch 30/30
# 359/359 - 145s - loss: 0.4020 - accuracy: 0.8545 - val_loss: 1.5266 - val_accuracy: 0.5399
# Epoch 1/30
# 359/359 - 145s - loss: 1.6726 - accuracy: 0.3404 - val_loss: 1.7938 - val_accuracy: 0.3063
# Epoch 2/30
# 359/359 - 145s - loss: 1.4171 - accuracy: 0.4564 - val_loss: 1.5778 - val_accuracy: 0.3905
# Epoch 3/30
# 359/359 - 146s - loss: 1.2963 - accuracy: 0.5025 - val_loss: 1.4383 - val_accuracy: 0.4343
# Epoch 4/30
# 359/359 - 144s - loss: 1.2153 - accuracy: 0.5367 - val_loss: 1.2643 - val_accuracy: 0.5216
# Epoch 5/30
# 359/359 - 145s - loss: 1.1439 - accuracy: 0.5686 - val_loss: 1.3991 - val_accuracy: 0.4768
# Epoch 6/30
# 359/359 - 144s - loss: 1.0876 - accuracy: 0.5924 - val_loss: 1.8072 - val_accuracy: 0.3192
# Epoch 7/30
# 359/359 - 148s - loss: 1.0374 - accuracy: 0.6070 - val_loss: 1.3035 - val_accuracy: 0.5071
# Epoch 8/30
# 359/359 - 144s - loss: 0.9877 - accuracy: 0.6274 - val_loss: 1.5084 - val_accuracy: 0.3952
# Epoch 9/30
# 359/359 - 145s - loss: 0.9288 - accuracy: 0.6537 - val_loss: 1.2241 - val_accuracy: 0.5343
# Epoch 10/30
# 359/359 - 144s - loss: 0.8826 - accuracy: 0.6739 - val_loss: 1.6439 - val_accuracy: 0.3915
# Epoch 11/30
# 359/359 - 146s - loss: 0.8341 - accuracy: 0.6905 - val_loss: 1.4262 - val_accuracy: 0.4798
# Epoch 12/30
# 359/359 - 143s - loss: 0.7946 - accuracy: 0.7085 - val_loss: 1.3030 - val_accuracy: 0.5268
# Epoch 13/30
# 359/359 - 146s - loss: 0.7506 - accuracy: 0.7242 - val_loss: 1.3041 - val_accuracy: 0.5179
# Epoch 14/30
# 359/359 - 146s - loss: 0.7078 - accuracy: 0.7408 - val_loss: 1.2743 - val_accuracy: 0.5467
# Epoch 15/30
# 359/359 - 147s - loss: 0.6692 - accuracy: 0.7563 - val_loss: 1.3440 - val_accuracy: 0.5249
# Epoch 16/30
# 359/359 - 143s - loss: 0.6265 - accuracy: 0.7710 - val_loss: 1.2615 - val_accuracy: 0.5427
# Epoch 17/30
# 359/359 - 145s - loss: 0.5977 - accuracy: 0.7813 - val_loss: 1.6533 - val_accuracy: 0.4281
# Epoch 18/30
# 359/359 - 143s - loss: 0.5652 - accuracy: 0.7927 - val_loss: 1.6099 - val_accuracy: 0.4789
# Epoch 19/30
# 359/359 - 146s - loss: 0.5304 - accuracy: 0.8056 - val_loss: 1.4915 - val_accuracy: 0.5054
# Epoch 20/30
# 359/359 - 143s - loss: 0.5089 - accuracy: 0.8142 - val_loss: 1.4026 - val_accuracy: 0.5357
# Epoch 21/30
# 359/359 - 145s - loss: 0.4799 - accuracy: 0.8269 - val_loss: 1.4863 - val_accuracy: 0.5082
# Epoch 22/30
# 359/359 - 144s - loss: 0.4475 - accuracy: 0.8362 - val_loss: 1.6423 - val_accuracy: 0.4946
# Epoch 23/30
# 359/359 - 147s - loss: 0.4420 - accuracy: 0.8379 - val_loss: 1.4919 - val_accuracy: 0.5357
# Epoch 24/30
# 359/359 - 144s - loss: 0.4207 - accuracy: 0.8485 - val_loss: 1.6047 - val_accuracy: 0.5152
# Epoch 25/30
# 359/359 - 146s - loss: 0.4027 - accuracy: 0.8524 - val_loss: 1.6666 - val_accuracy: 0.5244
# Epoch 26/30
# 359/359 - 144s - loss: 0.3859 - accuracy: 0.8583 - val_loss: 1.6179 - val_accuracy: 0.5310
# Epoch 27/30
# 359/359 - 147s - loss: 0.3602 - accuracy: 0.8704 - val_loss: 1.5313 - val_accuracy: 0.5442
# Epoch 28/30
# 359/359 - 145s - loss: 0.3649 - accuracy: 0.8684 - val_loss: 1.6084 - val_accuracy: 0.5246
# Epoch 29/30
# 359/359 - 144s - loss: 0.3427 - accuracy: 0.8737 - val_loss: 1.5731 - val_accuracy: 0.5463
# Epoch 30/30
# 359/359 - 143s - loss: 0.3344 - accuracy: 0.8782 - val_loss: 1.7816 - val_accuracy: 0.5376
# Epoch 1/30
# 359/359 - 338s - loss: 1.6537 - accuracy: 0.3595 - val_loss: 2.1021 - val_accuracy: 0.3002
# Epoch 2/30
# 359/359 - 337s - loss: 1.3749 - accuracy: 0.4738 - val_loss: 1.5003 - val_accuracy: 0.4276
# Epoch 3/30
# 359/359 - 334s - loss: 1.2470 - accuracy: 0.5296 - val_loss: 1.3511 - val_accuracy: 0.4929
# Epoch 4/30
# 359/359 - 339s - loss: 1.1483 - accuracy: 0.5670 - val_loss: 1.4288 - val_accuracy: 0.4511
# Epoch 5/30
# 359/359 - 338s - loss: 1.0645 - accuracy: 0.6041 - val_loss: 1.2407 - val_accuracy: 0.5416
# Epoch 6/30
# 359/359 - 335s - loss: 0.9727 - accuracy: 0.6390 - val_loss: 1.2339 - val_accuracy: 0.5395
# Epoch 7/30
# 359/359 - 335s - loss: 0.8879 - accuracy: 0.6747 - val_loss: 1.7645 - val_accuracy: 0.4159
# Epoch 8/30
# 359/359 - 334s - loss: 0.7874 - accuracy: 0.7149 - val_loss: 1.2566 - val_accuracy: 0.5418
# Epoch 9/30
# 359/359 - 336s - loss: 0.6892 - accuracy: 0.7512 - val_loss: 1.2568 - val_accuracy: 0.5441
# Epoch 10/30
# 359/359 - 337s - loss: 0.5908 - accuracy: 0.7883 - val_loss: 1.4608 - val_accuracy: 0.5179
# Epoch 11/30
# 359/359 - 334s - loss: 0.5043 - accuracy: 0.8235 - val_loss: 1.5874 - val_accuracy: 0.4742
# Epoch 12/30
# 359/359 - 337s - loss: 0.4301 - accuracy: 0.8501 - val_loss: 1.5064 - val_accuracy: 0.5373
# Epoch 13/30
# 359/359 - 334s - loss: 0.3546 - accuracy: 0.8750 - val_loss: 1.6615 - val_accuracy: 0.5272
# Epoch 14/30
# 359/359 - 334s - loss: 0.3147 - accuracy: 0.8902 - val_loss: 1.8077 - val_accuracy: 0.5310
# Epoch 15/30
# 359/359 - 338s - loss: 0.2700 - accuracy: 0.9090 - val_loss: 1.5247 - val_accuracy: 0.5590
# Epoch 16/30
# 359/359 - 333s - loss: 0.2274 - accuracy: 0.9204 - val_loss: 2.0699 - val_accuracy: 0.4890
# Epoch 17/30
# 359/359 - 334s - loss: 0.2075 - accuracy: 0.9295 - val_loss: 1.8185 - val_accuracy: 0.5500
# Epoch 18/30
# 359/359 - 334s - loss: 0.2014 - accuracy: 0.9316 - val_loss: 1.9108 - val_accuracy: 0.5462
# Epoch 19/30
# 359/359 - 336s - loss: 0.1708 - accuracy: 0.9409 - val_loss: 2.0597 - val_accuracy: 0.5401
# Epoch 20/30
# 359/359 - 334s - loss: 0.1636 - accuracy: 0.9468 - val_loss: 1.9162 - val_accuracy: 0.5670
# Epoch 21/30
# 359/359 - 337s - loss: 0.1500 - accuracy: 0.9491 - val_loss: 1.8709 - val_accuracy: 0.5618
# Epoch 22/30
# 359/359 - 336s - loss: 0.1466 - accuracy: 0.9494 - val_loss: 2.1228 - val_accuracy: 0.5366
# Epoch 23/30
# 359/359 - 335s - loss: 0.1400 - accuracy: 0.9525 - val_loss: 1.8964 - val_accuracy: 0.5637
# Epoch 24/30
# 359/359 - 333s - loss: 0.1274 - accuracy: 0.9573 - val_loss: 1.9225 - val_accuracy: 0.5557
# Epoch 25/30
# 359/359 - 334s - loss: 0.1241 - accuracy: 0.9570 - val_loss: 1.9262 - val_accuracy: 0.5740
# Epoch 26/30
# 359/359 - 334s - loss: 0.1211 - accuracy: 0.9583 - val_loss: 2.0789 - val_accuracy: 0.5228
# Epoch 27/30
# 359/359 - 332s - loss: 0.1229 - accuracy: 0.9595 - val_loss: 2.0341 - val_accuracy: 0.5582
# Epoch 28/30
# 359/359 - 332s - loss: 0.1088 - accuracy: 0.9618 - val_loss: 2.2133 - val_accuracy: 0.5221
# Epoch 29/30
# 359/359 - 334s - loss: 0.1072 - accuracy: 0.9637 - val_loss: 2.0963 - val_accuracy: 0.5637
# Epoch 30/30
# 359/359 - 332s - loss: 0.0969 - accuracy: 0.9679 - val_loss: 2.0142 - val_accuracy: 0.5599
# Epoch 1/30
# 359/359 - 337s - loss: 1.6334 - accuracy: 0.3595 - val_loss: 1.9694 - val_accuracy: 0.3297
# Epoch 2/30
# 359/359 - 333s - loss: 1.3509 - accuracy: 0.4808 - val_loss: 1.5720 - val_accuracy: 0.3873
# Epoch 3/30
# 359/359 - 335s - loss: 1.2205 - accuracy: 0.5366 - val_loss: 1.3447 - val_accuracy: 0.4815
# Epoch 4/30
# 359/359 - 335s - loss: 1.1175 - accuracy: 0.5800 - val_loss: 1.4061 - val_accuracy: 0.4932
# Epoch 5/30
# 359/359 - 335s - loss: 1.0242 - accuracy: 0.6168 - val_loss: 1.3466 - val_accuracy: 0.4936
# Epoch 6/30
# 359/359 - 334s - loss: 0.9334 - accuracy: 0.6501 - val_loss: 1.2951 - val_accuracy: 0.5185
# Epoch 7/30
# 359/359 - 336s - loss: 0.8338 - accuracy: 0.6931 - val_loss: 1.3084 - val_accuracy: 0.5052
# Epoch 8/30
# 359/359 - 335s - loss: 0.7330 - accuracy: 0.7304 - val_loss: 1.2709 - val_accuracy: 0.5380
# Epoch 9/30
# 359/359 - 334s - loss: 0.6344 - accuracy: 0.7700 - val_loss: 1.3952 - val_accuracy: 0.5186
# Epoch 10/30
# 359/359 - 334s - loss: 0.5362 - accuracy: 0.8067 - val_loss: 1.4581 - val_accuracy: 0.5089
# Epoch 11/30
# 359/359 - 334s - loss: 0.4395 - accuracy: 0.8439 - val_loss: 1.5079 - val_accuracy: 0.5263
# Epoch 12/30
# 359/359 - 336s - loss: 0.3764 - accuracy: 0.8683 - val_loss: 1.5761 - val_accuracy: 0.5528
# Epoch 13/30
# 359/359 - 333s - loss: 0.3020 - accuracy: 0.8933 - val_loss: 1.5107 - val_accuracy: 0.5341
# Epoch 14/30
# 359/359 - 337s - loss: 0.2710 - accuracy: 0.9057 - val_loss: 1.6070 - val_accuracy: 0.5660
# Epoch 15/30
# 359/359 - 335s - loss: 0.2260 - accuracy: 0.9208 - val_loss: 1.7756 - val_accuracy: 0.5312
# Epoch 16/30
# 359/359 - 333s - loss: 0.1995 - accuracy: 0.9319 - val_loss: 1.7086 - val_accuracy: 0.5566
# Epoch 17/30
# 359/359 - 333s - loss: 0.1917 - accuracy: 0.9340 - val_loss: 2.0662 - val_accuracy: 0.5037
# Epoch 18/30
# 359/359 - 338s - loss: 0.1719 - accuracy: 0.9408 - val_loss: 2.0438 - val_accuracy: 0.5470
# Epoch 19/30
# 359/359 - 332s - loss: 0.1649 - accuracy: 0.9423 - val_loss: 1.8969 - val_accuracy: 0.5693
# Epoch 20/30
# 359/359 - 332s - loss: 0.1488 - accuracy: 0.9506 - val_loss: 2.1950 - val_accuracy: 0.5226
# Epoch 21/30
# 359/359 - 332s - loss: 0.1332 - accuracy: 0.9545 - val_loss: 2.0235 - val_accuracy: 0.5446
# Epoch 22/30
# Epoch 15/30
# 359/359 - 329s - loss: 0.4678 - accuracy: 0.8331 - val_loss: 1.3979 - val_accuracy: 0.5462
# Epoch 16/30
# 359/359 - 328s - loss: 0.4320 - accuracy: 0.8462 - val_loss: 1.8145 - val_accuracy: 0.4828
# Epoch 17/30
# 359/359 - 327s - loss: 0.3888 - accuracy: 0.8622 - val_loss: 1.6687 - val_accuracy: 0.4930
# Epoch 18/30
# 359/359 - 328s - loss: 0.3539 - accuracy: 0.8758 - val_loss: 1.3892 - val_accuracy: 0.5704
# Epoch 19/30
# 359/359 - 328s - loss: 0.3159 - accuracy: 0.8889 - val_loss: 1.6617 - val_accuracy: 0.5200
# Epoch 20/30
# 359/359 - 326s - loss: 0.2970 - accuracy: 0.8954 - val_loss: 1.6409 - val_accuracy: 0.5364
# Epoch 21/30
# 359/359 - 327s - loss: 0.2770 - accuracy: 0.9044 - val_loss: 1.6543 - val_accuracy: 0.5425
# Epoch 22/30
# 359/359 - 329s - loss: 0.2653 - accuracy: 0.9062 - val_loss: 1.6712 - val_accuracy: 0.5380
# Epoch 23/30
# 359/359 - 7524s - loss: 0.2448 - accuracy: 0.9152 - val_loss: 1.7622 - val_accuracy: 0.5190
# Epoch 24/30

# %%
def write_to_file2(final_accuracy, final_loss, val_accuracy, val_loss, 
                   learning_rate, batch_size, maxpool_param, dense_unit,
                   conv_param1, conv_param2, conv_param3):
    
    output_string = f"CNN: Test Accuracy is {final_accuracy}, Test Loss is {final_loss} \n"
    output_string += f"Val Accuracy is {val_accuracy}, Val Loss is {val_loss} \n"
    output_string += f"Batch size - {batch_size}, Learning Rate - {learning_rate}, Dense - {dense_unit} \n"
    output_string += f"Conv2D-1 - {conv_param1.GetString()} \n"
    output_string += f"Conv2D-2 - {conv_param2.GetString()} \n"
    output_string += f"Conv2D-3 - {conv_param3.GetString()} \n"
    
    file1 = open('cnn2_tests.txt', 'a')
    file1.write(output_string)
    file1.close()
    
def explore_model2(x, y):
    conv2ds_1 = [ConvulationParameters(features=64, kernel=(3,3), strides=(1,1), padding='same')]
    
    #ConvulationParameters(features=128, kernel=(5,5), strides=(1,1), padding='same')
    conv2ds_2 = [ConvulationParameters(features=128, kernel=(3,3), strides=(1,1), padding='same')]
    
    #ConvulationParameters(features=512, kernel=(3,3), strides=(1,1), padding='same')
    conv2ds_3 = [ConvulationParameters(features=256, kernel=(3,3), strides=(1,1), padding='same')]
    
    maxpool_param = MaxPoolParameters(pool=(2,2), stride=(2,2))
    dense_units = [128] #256
    batch_size = 64
    learning_rate = 0.01
    
    for dense_unit in dense_unit:
        for conv_param1 in conv2ds_1:
            for conv_param2 in conv2ds_2:
                for conv_param3 in conv2ds_3:
                    model = generateCNN2(conv_param1, conv_param2, conv_param3, maxpool_param, dense_unit)
                    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
                    history = model.fit(x=x, y=y, batch_size=batch_size, epochs=1, validation_split=0.2, verbose=2)
                    final_accuracy, final_loss = history.history['accuracy'][-1], history.history['loss'][-1]
                    val_accuracy, val_loss = history.history['val_accuracy'][-1], history.history['val_loss'][-1]
                    write_to_file2(final_accuracy, final_loss, val_accuracy, val_loss, learning_rate, batch_size, 
                                   maxpool_param, dense_unit, conv_param1, conv_param2, conv_param3)

# %%
explore_model2(x, y)

# %%
def write_to_file3(final_accuracy, final_loss, val_accuracy, val_loss, 
                   learning_rate, batch_size, maxpool_param, dense_unit,
                   dropout_rate, conv_param1, conv_param2, conv_param3, 
                   conv_param4):
    
    output_string = f"CNN: Test Accuracy is {final_accuracy}, Test Loss is {final_loss} \n"
    output_string += f"Val Accuracy is {val_accuracy}, Val Loss is {val_loss} \n"
    output_string += f"Batch size - {batch_size}, Learning Rate - {learning_rate}, Dense - {dense_unit}, Dropout - {dropout_rate} \n"
    output_string += f"Conv2D-1 - {conv_param1.GetString()} \n"
    output_string += f"Conv2D-2 - {conv_param2.GetString()} \n"
    output_string += f"Conv2D-3 - {conv_param3.GetString()} \n"
    output_string += f"Conv2D-4 - {conv_param3.GetString()} \n"
    
    file1 = open('cnn3_tests.txt', 'a')
    file1.write(output_string)
    file1.close()
    
def explore_model3(x, y):
    conv_param1 = ConvulationParameters(features=64, kernel=(3,3), strides=(1,1), padding='same')
    
    conv_param2 = ConvulationParameters(features=128, kernel=(5,5), strides=(1,1), padding='same')
    
    #ConvulationParameters(features=256, kernel=(3,3), strides=(1,1), padding='same'),
    conv2ds_3 = [ConvulationParameters(features=512, kernel=(3,3), strides=(1,1), padding='same')]
    
    #ConvulationParameters(features=256, kernel=(3,3), strides=(1,1), padding='same'),
    conv2ds_4 = [ConvulationParameters(features=512, kernel=(3,3), strides=(1,1), padding='same')]
    
    maxpool_param = MaxPoolParameters(pool=(2,2), stride=(2,2))
    dense_units = [256] #128
    batch_size = 64
    dropout_rate = 0.2
    learning_rate = 0.001
    
    for dense_unit in dense_units:
        for conv_param3 in conv2ds_3:
            for conv_param4 in conv2ds_4:
                model = generateCNN3(conv_param1, conv_param2, conv_param3, conv_param4, maxpool_param, dense_unit, dropout_rate)
                model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
                history = model.fit(x=x, y=y, batch_size=batch_size, epochs=30, validation_split=0.2, verbose=2)
                                    
                final_accuracy, final_loss = history.history['accuracy'][-1], history.history['loss'][-1]
                val_accuracy, val_loss = history.history['val_accuracy'][-1], history.history['val_loss'][-1]
                                    
                write_to_file3(final_accuracy, final_loss, val_accuracy, val_loss, learning_rate, batch_size, 
                               maxpool_param, dense_unit, dropout_rate, conv_param1, conv_param2, conv_param3,
                               conv_param4)

# %%
explore_model3(x=x_train, y=y_train)
# Out:
# Epoch 1/30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-047a2bcec211> in <module>
# ----> 1 explore_model3(x=x_train, y=y_train)
#
# <ipython-input-10-97749c1b8267> in explore_model3(x, y)
#      38                 model = generateCNN3(conv_param1, conv_param2, conv_param3, conv_param4, maxpool_param, dense_unit, dropout_rate)
#      39                 model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
# ---> 40                 history = model.fit(x=x, y=y, batch_size=batch_size, epochs=30, validation_split=0.2, verbose=2)
#      41
#      42                 final_accuracy, final_loss = history.history['accuracy'][-1], history.history['loss'][-1]
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/gpu/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
